# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome(r"C:\Users\monis\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\monis\AppData\Local\Temp/ipykernel_12080/3168778916.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\monis\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.geeksforgeeks.org/scrape-linkedin-using-selenium-and-beautiful-soup-in-python/#:~:text=To%20extract%20data%2C%20firstly%2C%20store%20the%20source%20code,soup%20%3D%20BeautifulSoup%20%28src%2C%20%27lxml%27%29%20Extracting%20Profile%20Introduction%3A")

# waiting for the page to load
time.sleep(5)

# %%
print(soup)
# Out:
# <html class="client-js" dir="ltr" lang="en"><head>
# <meta charset="utf-8"/>
# <title>Portal:Current events - Wikipedia</title>
# ...

# %%
src = driver.page_source

# Now using beautiful soup
soup = BeautifulSoup(src, 'lxml')

# %%
print(soup)
# Out:
# <html lang="en-us" prefix="og: http://ogp.me/ns#"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/><meta content="#308D46" name="theme-color"/><meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png" name="image" property="og:image"/><meta content="image/png" property="og:image:type"/><meta content="200" property="og:image:width"/><meta content="200" property="og:image:height"/><script async="" crossorigin="anonymous" integrity="sha384-7qNxw2zDEIMk3jIadsSmzC0kkGqmjiFq+pQ5PCw6OX1M1QpaZ6FnQnk7obp3mDJZ" src="https://www.gstatic.com/recaptcha/releases/0aeEuuJmrVqDrEL39Fsg5-UJ/recaptcha__en.js" type="text/javascript"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://w
# ...

# %%
proftags = soup.findAll(
    'code',{"class":"plain"})
proftags
# Out:
# [<code class="plain">selenium </code>,
#  <code class="plain">webdriver</code>,
#  <code class="plain">bs4 </code>,
#  <code class="plain">BeautifulSoup</code>,
#  <code class="plain">time</code>,
#  <code class="plain">driver </code>,
#  <code class="plain">webdriver.Chrome(</code>,
#  <code class="plain">)</code>,
#  <code class="plain">driver.get(</code>,
#  <code class="plain">)</code>,
#  <code class="plain">time.sleep(</code>,
#  <code class="plain">)</code>,
#  <code class="plain">username </code>,
#  <code class="plain">driver.find_element_by_id(</code>,
#  <code class="plain">)</code>,
#  <code class="plain">username.send_keys(</code>,
#  <code class="plain">)  </code>,
#  <code class="plain">pword </code>,
#  <code class="plain">driver.find_element_by_id(</code>,
#  <code class="plain">)</code>,
#  <code class="plain">pword.send_keys(</code>,
#  <code class="plain">)        </code>,
#  <code class="plain">driver.find_element_by_xpath(</code>,
# ...

# %%
for mytag in proftags:
    print(mytag.get_text())
# Out:
# selenium
# webdriver
# bs4
# BeautifulSoup
# time
# driver
# webdriver.Chrome(
# )
# driver.get(
# )
# time.sleep(
# )
# username
# driver.find_element_by_id(
# )
# username.send_keys(
# )
# pword
# driver.find_element_by_id(
# )
# pword.send_keys(
# )
# driver.find_element_by_xpath(
# ).click()
# selenium
# webdriver
# bs4
# BeautifulSoup
# time
# driver
# webdriver.Chrome(
# )
# driver.get(
# )
# time.sleep(
# )
# username
# driver.find_element_by_id(
# )
# username.send_keys("")
# pword
# driver.find_element_by_id(
# )
# pword.send_keys("")
# driver.find_element_by_xpath(
# ).click()
# profile_url
# driver.get(profile_url)
# start
# time.time()
# initialScroll
# finalScroll
# :
# driver.execute_script(f"window.scrollTo({initialScroll},
# {finalScroll})
# ")
# initialScroll
# finalScroll
# finalScroll
# time.sleep(
# )
# end
# time.time()
# (end
# start) >
# :
# src
# driver.page_source
# soup
# BeautifulSoup(src,
# )
# intro
# soup.find(
# , {
# :
# })
# (intro)
# name_loc
# ...

# %%
# entering username
username = driver.find_element_by_id("username")

# In case of an error, try changing the element
# tag used here.

# Enter Your Email Address
username.send_keys("User_email")

# entering password
pword = driver.find_element_by_id("password")
# In case of an error, try changing the element
# tag used here.

# Enter Your Password
pword.send_keys("User_pass")		

# Clicking on the log in button
# Format (syntax) of writing XPath -->
# //tagname[@attribute='value']
driver.find_element_by_xpath("//button[@type='submit']").click()
# In case of an error, try changing the
# XPath used here.
